# %% [markdown]
# # Experimento Mixto Avanzado: Sequential Transfer Learning (Multi-Model)
#
# Este notebook implementa una estrategia de **Sequential Transfer Learning** para detectar corrosión.
# El proceso consta de dos fases para cada modelo (Nano, Medium, Large):
# 1.  **Fase 1 (Pre-entrenamiento Aéreo):** El modelo aprende características generales de corrosión usando un dataset aéreo.
# 2.  **Fase 2 (Fine-Tuning Submarino):** El modelo adapta su conocimiento al dominio submarino (objetivo), con una tasa de aprendizaje baja y backbone congelado inicialmente.

# %%
import shutil
from pathlib import Path
import torch
from ultralytics import YOLO
import os

# %%
# --- CONFIGURACIÓN GLOBAL ---
# Asegúrate de que estas rutas existen
ACUATICO_DIR = Path("./dataset_yolo")       
AEREO_DIR = Path("./dataset_aereo")         
OUTPUT_DIR = Path("./modelos_entrenados")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Parámetros Globales
PROJECT_NAME = "Sequential_Transfer_Benchmark"
EPOCHS_AEREO = 30         
EPOCHS_FINE_TUNE = 50     

print(f"\n{'='*60}")
print(f" ESTRATEGIA: SEQUENTIAL TRANSFER LEARNING (MULTI-MODEL)")
print(f" Fase 1: Aprender Corrosión Aérea -> Fase 2: Adaptar a Submarino")
print(f"{'='*60}")

# --- PREPARACIÓN DE YAMLs ---

# 1. Crear YAML Aéreo temporal (CON EL FIX DE VALIDACIÓN)
yaml_aereo = Path("temp_aereo.yaml")
with open(yaml_aereo, "w") as f:
    # TRUCO: Usamos 'train' también como 'val' porque el dataset aéreo no tiene split
    # Esto evita el error "missing path .../val"
    train_path = (AEREO_DIR / "images/train").absolute()
    
    f.write(f"path: {AEREO_DIR.absolute()}\n")
    f.write(f"train: {train_path}\n")
    f.write(f"val: {train_path}\n")  # <--- AQUÍ ESTÁ EL FIX
    f.write("names:\n  0: corrosion")

# 2. Crear YAML Submarino (Usamos tu dataset limpio original)
yaml_acuatico = Path("temp_acuatico.yaml")
with open(yaml_acuatico, "w") as f:
    # Asumimos que dataset_yolo SÍ tiene estructura correcta (images/train, images/val)
    # Si usaste K-Fold antes, dataset_yolo original puede no tener 'val' fijo.
    # Usaremos el dataset_yolo_aug/dataset.yml si existe, o apuntamos al original.
    
    # Opción A: Usar el dataset original directo (YOLO hará un split automático si solo hay train)
    f.write(f"path: {ACUATICO_DIR.absolute()}\n")
    f.write("train: images/train\n")
    
    # Verificamos si existe val, si no, usamos train (YOLO dividirá auto)
    if (ACUATICO_DIR / "images/val").exists():
        f.write("val: images/val\n")
    elif (ACUATICO_DIR / "images/valid").exists():
        f.write("val: images/valid\n")
    else:
        # Si no hay val, usamos train y dejamos que YOLO se queje o use train
        f.write("val: images/train\n") 
        
    f.write("names:\n  0: corrosion")

print("✅ Archivos YAML de configuración creados.")
# Out:
# ============================================================
#  ESTRATEGIA: SEQUENTIAL TRANSFER LEARNING (MULTI-MODEL)
#  Fase 1: Aprender Corrosión Aérea -> Fase 2: Adaptar a Submarino
# ============================================================
# ✅ Archivos YAML de configuración creados.

# %% [markdown]
# ## 1. Entrenamiento Modelo NANO (yolo12n)
# **Batch Size:** 32 (Modelo ligero, permite batch alto)

# %%
MODEL_ARCH = "yolo12n.pt"
BATCH_SIZE = 32
model_name_clean = "yolo12n"

print(f"\n\n{'#'*60}")
print(f" INICIANDO PROCESO PARA MODELO: {model_name_clean}")
print(f"{'#'*60}")

# --- FASE 1: PRE-ENTRENAMIENTO AÉREO ---
print(f"\n>>> [{model_name_clean}] FASE 1: ENTRENAMIENTO EN DOMINIO AÉREO (FUENTE)")

model_phase1 = YOLO(MODEL_ARCH)
model_phase1.train(
    data=str(yaml_aereo),
    epochs=EPOCHS_AEREO,
    imgsz=640,
    batch=BATCH_SIZE,
    project=PROJECT_NAME,
    name=f"phase1_aerial_{model_name_clean}",
    exist_ok=True,
    verbose=True, 
    optimizer='SGD',
    lr0=0.01
)

# Recuperar los pesos resultantes de la Fase 1
weights_phase1 = Path(PROJECT_NAME) / f"phase1_aerial_{model_name_clean}" / "weights" / "best.pt"
print(f"✅ [{model_name_clean}] Fase 1 Completada. Pesos 'Expertos en Aire' guardados en: {weights_phase1}")

# --- FASE 2: FINE-TUNING SUBMARINO ---
print(f"\n>>> [{model_name_clean}] FASE 2: FINE-TUNING EN DOMINIO SUBMARINO (OBJETIVO)")

if weights_phase1.exists():
    model_phase2 = YOLO(weights_phase1)

    # 3. Entrenar (Fine-Tuning)
    model_phase2.train(
        data=str(yaml_acuatico),
        epochs=EPOCHS_FINE_TUNE,
        imgsz=640,
        batch=BATCH_SIZE,
        project=PROJECT_NAME,
        name=f"phase2_underwater_{model_name_clean}",
        exist_ok=True,
        optimizer='SGD',
        lr0=0.005,      # LR Bajo
        lrf=0.1,
        freeze=10,      # Congelar backbone
        augment=True    
    )

    # Guardar resultado final
    final_weights = Path(PROJECT_NAME) / f"phase2_underwater_{model_name_clean}" / "weights" / "best.pt"
    dest = OUTPUT_DIR / f"modelo-mixto-n.pt"
    
    if final_weights.exists():
        shutil.copy(final_weights, dest)
        print(f"\n✅ MODELO MIXTO SECUENCIAL GUARDADO: {dest}")

        # --- VALIDACIÓN FINAL ---
        print(f"\nValidando el nuevo modelo {model_name_clean}...")
        test_yaml = './dataset_yolo/dataset.yml' 
        try:
            metrics = model_phase2.val(split='test', data=test_yaml)
            print(f"[{model_name_clean}] mAP@50 Final: {metrics.box.map50:.4f}")
        except Exception as e:
            print(f"No se pudo validar automáticamente. Error: {e}")
    else:
        print("Error: No se generaron pesos en la Fase 2.")
else:
    print(f"❌ Error Crítico: No se encontró el modelo de la Fase 1 en {weights_phase1}")
# Out:
# ############################################################
#  INICIANDO PROCESO PARA MODELO: yolo12n
# ############################################################
#
# >>> [yolo12n] FASE 1: ENTRENAMIENTO EN DOMINIO AÉREO (FUENTE)
# New https://pypi.org/project/ultralytics/8.3.233 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228 🚀 Python-3.9.13 torch-2.8.0+cu128 CPU (AMD Ryzen 7 5800X 8-Core Processor)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=temp_aereo.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=phase1_aerial_yolo12n, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=Sequential_Transfer_Benchmark, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/user/work/EONSEA/Articulo-Corrosion/Sequential_Transfer_Benchmark/phase1_aerial_yolo12n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,568,243 parameters, 2,568,227 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1992.4±843.3 MB/s, size: 32.7 KB)
# train: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train... 35259 images, 7284 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35259/35259 2.2Kit/s 15.7s<0.1s
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000097.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000242.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000351.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000492.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000700.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000870.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001085.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001512.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/005238.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/008311.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/014068.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/016913.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/017847.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018347.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018726.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/020864.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/022157.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026345.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026794.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/029246.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031530.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031652.jpg: 2 duplicate labels removed
# train: New cache created: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train.cache
# albumentations: __init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2756.7±921.9 MB/s, size: 34.3 KB)
# val: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train.cache... 35259 images, 7284 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35259/35259 70.5Mit/s 0.0s
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000097.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000242.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000351.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000492.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000700.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000870.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001085.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001512.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/005238.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/008311.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/014068.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/016913.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/017847.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018347.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018726.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/020864.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/022157.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026345.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026794.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/029246.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031530.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031652.jpg: 2 duplicate labels removed
# Plotting labels to /home/user/work/EONSEA/Articulo-Corrosion/Sequential_Transfer_Benchmark/phase1_aerial_yolo12n/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /home/user/work/EONSEA/Articulo-Corrosion/Sequential_Transfer_Benchmark/phase1_aerial_yolo12n
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30         0G      1.952      3.336      1.842        158        640: 0% ──────────── 2/1102 14.4s/it 22.4s<4:24:08
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 13
#      10 print(f"\n>>> [{model_name_clean}] FASE 1: ENTRENAMIENTO EN DOMINIO AÉREO (FUENTE)")
#      12 model_phase1 = YOLO(MODEL_ARCH)
# ---> 13 model_phase1.train(
#      14     data=str(yaml_aereo),
#      15     epochs=EPOCHS_AEREO,
#      16     imgsz=640,
#      17     batch=BATCH_SIZE,
#      18     project=PROJECT_NAME,
#      19     name=f"phase1_aerial_{model_name_clean}",
#      20     exist_ok=True,
#      21     verbose=True,
#      22     optimizer='SGD',
#      23     lr0=0.01
#      24 )
#      26 # Recuperar los pesos resultantes de la Fase 1
#      27 weights_phase1 = Path(PROJECT_NAME) / f"phase1_aerial_{model_name_clean}" / "weights" / "best.pt"
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/model.py:778, in Model.train(self, trainer, **kwargs)
#     775     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     776     self.model = self.trainer.model
# --> 778 self.trainer.train()
#     779 # Update model and cfg after training
#     780 if RANK in {-1, 0}:
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/trainer.py:434, in BaseTrainer._do_train(self)
#     431     self.tloss = self.loss_items if self.tloss is None else (self.tloss * i + self.loss_items) / (i + 1)
#     433 # Backward
# --> 434 self.scaler.scale(self.loss).backward()
#     435 if ni - last_opt_step >= self.accumulate:
#     436     self.optimizer_step()
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/torch/_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/torch/autograd/graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2. Entrenamiento Modelo MEDIUM (yolo12m)
# **Batch Size:** 16 (Equilibrio memoria/rendimiento)

# %%
MODEL_ARCH = "yolo12m.pt"
BATCH_SIZE = 16
model_name_clean = "yolo12m"

print(f"\n\n{'#'*60}")
print(f" INICIANDO PROCESO PARA MODELO: {model_name_clean}")
print(f"{'#'*60}")

# --- FASE 1: PRE-ENTRENAMIENTO AÉREO ---
print(f"\n>>> [{model_name_clean}] FASE 1: ENTRENAMIENTO EN DOMINIO AÉREO (FUENTE)")

model_phase1 = YOLO(MODEL_ARCH)
model_phase1.train(
    data=str(yaml_aereo),
    epochs=EPOCHS_AEREO,
    imgsz=640,
    batch=BATCH_SIZE,
    project=PROJECT_NAME,
    name=f"phase1_aerial_{model_name_clean}",
    exist_ok=True,
    verbose=True, 
    optimizer='SGD',
    lr0=0.01
)

# Recuperar los pesos resultantes de la Fase 1
weights_phase1 = Path(PROJECT_NAME) / f"phase1_aerial_{model_name_clean}" / "weights" / "best.pt"
print(f"✅ [{model_name_clean}] Fase 1 Completada. Pesos 'Expertos en Aire' guardados en: {weights_phase1}")

# --- FASE 2: FINE-TUNING SUBMARINO ---
print(f"\n>>> [{model_name_clean}] FASE 2: FINE-TUNING EN DOMINIO SUBMARINO (OBJETIVO)")

if weights_phase1.exists():
    model_phase2 = YOLO(weights_phase1)

    # 3. Entrenar (Fine-Tuning)
    model_phase2.train(
        data=str(yaml_acuatico),
        epochs=EPOCHS_FINE_TUNE,
        imgsz=640,
        batch=BATCH_SIZE,
        project=PROJECT_NAME,
        name=f"phase2_underwater_{model_name_clean}",
        exist_ok=True,
        optimizer='SGD',
        lr0=0.005,      # LR Bajo
        lrf=0.1,
        freeze=10,      # Congelar backbone
        augment=True    
    )

    # Guardar resultado final
    final_weights = Path(PROJECT_NAME) / f"phase2_underwater_{model_name_clean}" / "weights" / "best.pt"
    dest = OUTPUT_DIR / f"modelo-mixto-m.pt"
    
    if final_weights.exists():
        shutil.copy(final_weights, dest)
        print(f"\n✅ MODELO MIXTO SECUENCIAL GUARDADO: {dest}")

        # --- VALIDACIÓN FINAL ---
        print(f"\nValidando el nuevo modelo {model_name_clean}...")
        test_yaml = './dataset_yolo/dataset.yml' 
        try:
            metrics = model_phase2.val(split='test', data=test_yaml)
            print(f"[{model_name_clean}] mAP@50 Final: {metrics.box.map50:.4f}")
        except Exception as e:
            print(f"No se pudo validar automáticamente. Error: {e}")
    else:
        print("Error: No se generaron pesos en la Fase 2.")
else:
    print(f"❌ Error Crítico: No se encontró el modelo de la Fase 1 en {weights_phase1}")
# Out:
# ############################################################
#  INICIANDO PROCESO PARA MODELO: yolo12m
# ############################################################
#
# >>> [yolo12m] FASE 1: ENTRENAMIENTO EN DOMINIO AÉREO (FUENTE)
# New https://pypi.org/project/ultralytics/8.3.233 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228 🚀 Python-3.9.13 torch-2.8.0+cu128 CPU (AMD Ryzen 7 5800X 8-Core Processor)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=temp_aereo.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=phase1_aerial_yolo12m, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=Sequential_Transfer_Benchmark, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/user/work/EONSEA/Articulo-Corrosion/Sequential_Transfer_Benchmark/phase1_aerial_yolo12m, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLOv12m summary: 292 layers, 20,138,259 parameters, 20,138,243 gradients, 67.7 GFLOPs
#
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2716.2±1202.9 MB/s, size: 34.0 KB)
# train: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train.cache... 35259 images, 7284 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35259/35259 72.8Mit/s 0.0s
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000097.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000242.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000351.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000492.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000700.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000870.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001085.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001512.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/005238.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/008311.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/014068.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/016913.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/017847.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018347.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018726.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/020864.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/022157.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026345.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026794.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/029246.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031530.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031652.jpg: 2 duplicate labels removed
# albumentations: __init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2489.4±947.5 MB/s, size: 30.2 KB)
# val: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train.cache... 35259 images, 7284 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35259/35259 73.9Mit/s 0.0s
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000097.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000242.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000351.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000492.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000700.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000870.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001085.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001512.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/005238.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/008311.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/014068.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/016913.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/017847.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018347.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018726.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/020864.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/022157.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026345.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026794.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/029246.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031530.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031652.jpg: 2 duplicate labels removed
# Plotting labels to /home/user/work/EONSEA/Articulo-Corrosion/Sequential_Transfer_Benchmark/phase1_aerial_yolo12m/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /home/user/work/EONSEA/Articulo-Corrosion/Sequential_Transfer_Benchmark/phase1_aerial_yolo12m
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# : 0% ──────────── 0/2204  2.5s
# KeyboardInterrupt

# %% [markdown]
# ## 3. Entrenamiento Modelo LARGE (yolo12l)
# **Batch Size:** 8 (Modelo pesado, reducir batch para evitar OOM)

# %%
MODEL_ARCH = "yolo12l.pt"
BATCH_SIZE = 8
model_name_clean = "yolo12l"

print(f"\n\n{'#'*60}")
print(f" INICIANDO PROCESO PARA MODELO: {model_name_clean}")
print(f"{'#'*60}")

# --- FASE 1: PRE-ENTRENAMIENTO AÉREO ---
print(f"\n>>> [{model_name_clean}] FASE 1: ENTRENAMIENTO EN DOMINIO AÉREO (FUENTE)")

model_phase1 = YOLO(MODEL_ARCH)
model_phase1.train(
    data=str(yaml_aereo),
    epochs=EPOCHS_AEREO,
    imgsz=640,
    batch=BATCH_SIZE,
    project=PROJECT_NAME,
    name=f"phase1_aerial_{model_name_clean}",
    exist_ok=True,
    verbose=True, 
    optimizer='SGD',
    lr0=0.01
)

# Recuperar los pesos resultantes de la Fase 1
weights_phase1 = Path(PROJECT_NAME) / f"phase1_aerial_{model_name_clean}" / "weights" / "best.pt"
print(f"✅ [{model_name_clean}] Fase 1 Completada. Pesos 'Expertos en Aire' guardados en: {weights_phase1}")

# --- FASE 2: FINE-TUNING SUBMARINO ---
print(f"\n>>> [{model_name_clean}] FASE 2: FINE-TUNING EN DOMINIO SUBMARINO (OBJETIVO)")

if weights_phase1.exists():
    model_phase2 = YOLO(weights_phase1)

    # 3. Entrenar (Fine-Tuning)
    model_phase2.train(
        data=str(yaml_acuatico),
        epochs=EPOCHS_FINE_TUNE,
        imgsz=640,
        batch=BATCH_SIZE,
        project=PROJECT_NAME,
        name=f"phase2_underwater_{model_name_clean}",
        exist_ok=True,
        optimizer='SGD',
        lr0=0.005,      # LR Bajo
        lrf=0.1,
        freeze=10,      # Congelar backbone
        augment=True    
    )

    # Guardar resultado final
    final_weights = Path(PROJECT_NAME) / f"phase2_underwater_{model_name_clean}" / "weights" / "best.pt"
    dest = OUTPUT_DIR / f"modelo-mixto-l.pt"
    
    if final_weights.exists():
        shutil.copy(final_weights, dest)
        print(f"\n✅ MODELO MIXTO SECUENCIAL GUARDADO: {dest}")

        # --- VALIDACIÓN FINAL ---
        print(f"\nValidando el nuevo modelo {model_name_clean}...")
        test_yaml = './dataset_yolo/dataset.yml' 
        try:
            metrics = model_phase2.val(split='test', data=test_yaml)
            print(f"[{model_name_clean}] mAP@50 Final: {metrics.box.map50:.4f}")
        except Exception as e:
            print(f"No se pudo validar automáticamente. Error: {e}")
    else:
        print("Error: No se generaron pesos en la Fase 2.")
else:
    print(f"❌ Error Crítico: No se encontró el modelo de la Fase 1 en {weights_phase1}")
# Out:
# ############################################################
#  INICIANDO PROCESO PARA MODELO: yolo12l
# ############################################################
#
# >>> [yolo12l] FASE 1: ENTRENAMIENTO EN DOMINIO AÉREO (FUENTE)
# New https://pypi.org/project/ultralytics/8.3.233 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228 🚀 Python-3.9.13 torch-2.8.0+cu128 CPU (AMD Ryzen 7 5800X 8-Core Processor)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=temp_aereo.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12l.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=phase1_aerial_yolo12l, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=Sequential_Transfer_Benchmark, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/user/work/EONSEA/Articulo-Corrosion/Sequential_Transfer_Benchmark/phase1_aerial_yolo12l, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  4   4272944  ultralytics.nn.modules.block.A2C2f           [512, 512, 4, True, 4, True, 1.2]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  4   4272944  ultralytics.nn.modules.block.A2C2f           [512, 512, 4, True, 1, True, 1.2]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  2   2102784  ultralytics.nn.modules.block.A2C2f           [1024, 512, 2, False, -1, True, 1.2]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  2    592640  ultralytics.nn.modules.block.A2C2f           [1024, 256, 2, False, -1, True, 1.2]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  2   2037248  ultralytics.nn.modules.block.A2C2f           [768, 512, 2, False, -1, True, 1.2]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  21        [14, 17, 20]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLOv12l summary: 488 layers, 26,389,875 parameters, 26,389,859 gradients, 89.4 GFLOPs
#
# Transferred 1239/1245 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2822.3±1098.8 MB/s, size: 34.0 KB)
# train: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train.cache... 35259 images, 7284 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35259/35259 78.6Mit/s 0.0s
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000097.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000242.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000351.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000492.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000700.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000870.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001085.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001512.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/005238.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/008311.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/014068.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/016913.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/017847.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018347.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018726.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/020864.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/022157.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026345.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026794.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/029246.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031530.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031652.jpg: 2 duplicate labels removed
# albumentations: __init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2522.1±966.6 MB/s, size: 30.2 KB)
# val: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train.cache... 35259 images, 7284 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35259/35259 73.5Mit/s 0.0s
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000097.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000242.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000351.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000492.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000700.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000870.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001085.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001512.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/005238.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/008311.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/014068.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/016913.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/017847.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018347.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018726.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/020864.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/022157.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026345.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026794.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/029246.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031530.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031652.jpg: 2 duplicate labels removed
# Plotting labels to /home/user/work/EONSEA/Articulo-Corrosion/Sequential_Transfer_Benchmark/phase1_aerial_yolo12l/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 205 weight(decay=0.0), 214 weight(decay=0.0005), 211 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /home/user/work/EONSEA/Articulo-Corrosion/Sequential_Transfer_Benchmark/phase1_aerial_yolo12l
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# : 0% ──────────── 0/4408  11.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 13
#      10 print(f"\n>>> [{model_name_clean}] FASE 1: ENTRENAMIENTO EN DOMINIO AÉREO (FUENTE)")
#      12 model_phase1 = YOLO(MODEL_ARCH)
# ---> 13 model_phase1.train(
#      14     data=str(yaml_aereo),
#      15     epochs=EPOCHS_AEREO,
#      16     imgsz=640,
#      17     batch=BATCH_SIZE,
#      18     project=PROJECT_NAME,
#      19     name=f"phase1_aerial_{model_name_clean}",
#      20     exist_ok=True,
#      21     verbose=True,
#      22     optimizer='SGD',
#      23     lr0=0.01
#      24 )
#      26 # Recuperar los pesos resultantes de la Fase 1
#      27 weights_phase1 = Path(PROJECT_NAME) / f"phase1_aerial_{model_name_clean}" / "weights" / "best.pt"
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/model.py:778, in Model.train(self, trainer, **kwargs)
#     775     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     776     self.model = self.trainer.model
# --> 778 self.trainer.train()
#     779 # Update model and cfg after training
#     780 if RANK in {-1, 0}:
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/trainer.py:434, in BaseTrainer._do_train(self)
#     431     self.tloss = self.loss_items if self.tloss is None else (self.tloss * i + self.loss_items) / (i + 1)
#     433 # Backward
# --> 434 self.scaler.scale(self.loss).backward()
#     435 if ni - last_opt_step >= self.accumulate:
#     436     self.optimizer_step()
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/torch/_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/torch/autograd/graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:
