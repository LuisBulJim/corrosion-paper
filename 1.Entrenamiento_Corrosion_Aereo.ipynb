# %% [markdown]
# # Entrenamiento de Modelos de Detección de Corrosión con YOLO

# %% [markdown]
# Este notebook contiene el proceso completo para entrenar modelos de detección de corrosión utilizando YOLO. Las principales etapas son:
#
# 1. **Instalación e importación de librerías**: Se instalan y cargan todas las dependencias necesarias.
# 2. **Obtención y preparación del dataset**: Se descarga un dataset de corrosión desde Roboflow, que consta de 5 versiones, y se fusionan en un único conjunto de datos.
# 3. **Unificación de clases**: Se procesan los archivos de etiquetas para unificar todas las clases en una sola categoría: `corrosion`.
# 4. **Entrenamiento de modelos**: Se entrenan dos arquitecturas de YOLO (Nano y Large) con el dataset preparado.
# 5. **Guardado de modelos**: Los mejores pesos (`best.pt`) de cada entrenamiento se guardan en una carpeta dedicada (`modelos_entrenados`).
# 6. **Visualización de métricas**: Se muestran las gráficas de rendimiento y las matrices de confusión para cada modelo entrenado.

# %% [markdown]
# ## 1. Instalación e Importación de Librerías

# %%
# !pip install ultralytics roboflow

import os
import shutil
import glob
import torch
import cv2
import matplotlib.pyplot as plt
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import display
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.232-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.9 MB/s eta 0:00:00a 0:00:01
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 13.8 MB/s eta 0:00:00
# Collecting opencv-python>=4.6.0
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 31.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/lib/python3.9/site-packages (from ultralytics) (1.23.4)
# Collecting ultralytics-thop>=2.0.18
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.9/site-packages (from ultralytics) (0.13.1+cu116)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.9/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.9/site-packages (from ultralytics) (9.2.0)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.9/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.9/site-packages (from ultralytics) (1.9.3)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.9/site-packages (from ultralytics) (1.12.1+cu116)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.9/site-packages (from ultralytics) (2.28.1)
# Collecting polars>=0.20.0
#   Downloading polars-1.35.2-py3-none-any.whl (783 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.6/783.6 kB 54.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.9/site-packages (from ultralytics) (3.6.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.9/site-packages (from roboflow) (1.4.4)
# Collecting pillow-avif-plugin<2
#   Downloading pillow_avif_plugin-1.5.2-cp39-cp39-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 61.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm>=4.41.0 in /opt/conda/lib/python3.9/site-packages (from roboflow) (4.64.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from roboflow) (2022.9.24)
# Collecting filetype
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: cycler in /opt/conda/lib/python3.9/site-packages (from roboflow) (0.11.0)
# Collecting idna==3.7
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 13.2 MB/s eta 0:00:00
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 10.8 MB/s eta 0:00:00
# Collecting opencv-python-headless==4.10.0.84
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 38.1 MB/s eta 0:00:0000:0100:01
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Collecting pi-heif<2
#   Downloading pi_heif-1.1.1-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 75.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.9/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: urllib3>=1.26.6 in /opt/conda/lib/python3.9/site-packages (from roboflow) (1.26.11)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.6)
# Collecting numpy>=1.23.0
#   Downloading numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 63.4 MB/s eta 0:00:0000:0100:01
# Collecting pillow>=7.1.2
#   Downloading pillow-11.3.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 83.5 MB/s eta 0:00:00:00:0100:01
# Collecting polars-runtime-32==1.35.2
#   Downloading polars_runtime_32-1.35.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 MB 43.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2.1.1)
# Collecting scipy>=1.4.1
#   Downloading scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 45.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (4.4.0)
# Installing collected packages: pillow-avif-plugin, filetype, python-dotenv, polars-runtime-32, pillow, numpy, idna, ultralytics-thop, scipy, polars, pi-heif, opencv-python-headless, opencv-python, requests-toolbelt, ultralytics, roboflow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.2.0
#     Uninstalling Pillow-9.2.0:
#       Successfully uninstalled Pillow-9.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.3 requires numpy<1.24,>=1.18, but you have numpy 2.0.2 which is incompatible.
# Successfully installed filetype-1.2.0 idna-3.7 numpy-2.0.2 opencv-python-4.12.0.88 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-11.3.0 pillow-avif-plugin-1.5.2 polars-1.35.2 polars-runtime-32-1.35.2 python-dotenv-1.2.1 requests-toolbelt-1.0.0 roboflow-1.2.11 scipy-1.13.1 ultralytics-8.3.232 ultralytics-thop-2.0.18
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/user/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## 2. Obtención y Preparación del Dataset

# %% [markdown]
# Se descarga el dataset de corrosión desde Roboflow. Este dataset está compuesto por 5 versiones diferentes que se fusionarán en un único conjunto de datos para el entrenamiento.
#
# Para la descarga es necesaria una API Key de Roboflow. Puedes encontrarla en la documentación oficial: https://docs.roboflow.com/api-reference/authentication

# %%
rf = Roboflow(api_key="jkNjmBUggWEmVWag4qo0") # Reemplaza con tu API Key
project = rf.workspace("universitas-diponegoro-rfxta").project("corrosion-hsmae")

# Ruta raíz para el dataset combinado
merged_root = "dataset_corrosion_merged"

# Se crean los subdirectorios para el dataset fusionado
splits = ["train", "valid", "test"]
for split in splits:
    os.makedirs(os.path.join(merged_root, "images", split), exist_ok=True)
    os.makedirs(os.path.join(merged_root, "labels", split), exist_ok=True)

image_counter = {"train": 0, "valid": 0, "test": 0}

# Se recorren las 5 versiones del dataset, se descargan y se fusionan
for version_num in range(1, 6):
    print(f"\nDescargando y procesando versión {version_num}...")
    version = project.version(version_num)
    dataset = version.download("yolov12")

    for split in splits:
        split_images_path = os.path.join(dataset.location, split, "images")
        split_labels_path = os.path.join(dataset.location, split, "labels")

        if os.path.exists(split_images_path) and os.path.exists(split_labels_path):
            for filename in os.listdir(split_images_path):
                # Se copia la imagen
                src_img = os.path.join(split_images_path, filename)
                dst_img = os.path.join(merged_root, "images", split, f"{image_counter[split]:06d}.jpg")
                shutil.copyfile(src_img, dst_img)

                # Se copia la etiqueta correspondiente
                label_name = filename.replace(".jpg", ".txt").replace(".png", ".txt")
                src_lbl = os.path.join(split_labels_path, label_name)
                dst_lbl = os.path.join(merged_root, "labels", split, f"{image_counter[split]:06d}.txt")

                if os.path.exists(src_lbl):
                    shutil.copyfile(src_lbl, dst_lbl)

                image_counter[split] += 1

print("\n¡Dataset completamente fusionado!")

# Se crea el archivo data.yaml necesario para el entrenamiento de YOLO
yaml_path = os.path.join(merged_root, "data.yaml")
with open(yaml_path, "w") as f:
    f.write(
        "train: images/train\n"
        "val: images/valid\n"
        "test: images/test\n"
        "\n"
        "nc: 1\n"
        "names: ['corrosion']\n"
    )

print(f"Archivo data.yaml creado en: {yaml_path}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
#
# Descargando y procesando versión 1...
# Downloading Dataset Version Zip in corrosion-1 to yolov12:: 100%|██████████| 44855/44855 [00:02<00:00, 19749.67it/s]
# Extracting Dataset Version Zip to corrosion-1 in yolov12:: 100%|██████████| 2142/2142 [00:00<00:00, 13430.46it/s]
# Descargando y procesando versión 2...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 19
#      17 print(f"\nDescargando y procesando versión {version_num}...")
#      18 version = project.version(version_num)
# ---> 19 dataset = version.download("yolov12")
#      21 for split in splits:
#      22     split_images_path = os.path.join(dataset.location, split, "images")
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/roboflow/core/version.py:241, in Version.download(self, model_format, location, overwrite)
#     237         raise RuntimeError(export_info)
#     239     link = export_info["export"]["link"]
# --> 241 self.__download_zip(link, location, model_format)
#     242 self.__extract_zip(location, model_format)
#     243 self.__reformat_yaml(location, model_format)  # TODO: is roboflow-python a place to be munging yaml files?
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/roboflow/core/version.py:559, in Version.__download_zip(self, link, location, format)
#     556     sys.stdout.flush()
#     558 try:
# --> 559     response = requests.get(link, stream=True)
#     561     # write the zip file to the desired location
#     562     with open(location + "/roboflow.zip", "wb") as f:
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/work/envs/yoloenv/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/work/envs/yoloenv/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/work/envs/yoloenv/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/work/envs/yoloenv/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/work/envs/yoloenv/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/work/envs/yoloenv/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3. Unificación de Clases de Corrosión

# %% [markdown]
# El dataset original contiene múltiples clases para la corrosión (ej. `korosi`, `oxido`). Para simplificar el problema, se unificarán todas estas clases en una única clase `corrosion` (índice 0).

# %%
def force_first_char_zero(labels_root):
    """
    Recorre todos los archivos .txt en los subdirectorios (train, valid, test)
    y cambia el primer carácter de cada línea a '0' para unificar la clase.
    """
    for split in ("train", "valid", "test"):
        folder = os.path.join(labels_root, split)
        for path in glob.glob(f"{folder}/*.txt"):
            with open(path, "r") as f:
                lines = f.read().splitlines()
            
            new_lines = []
            for line in lines:
                if not line.strip():
                    continue
                new_lines.append("0" + line[1:] + "\n")
            
            with open(path, "w") as f:
                f.writelines(new_lines)

labels_root = "dataset_corrosion_merged/labels"
force_first_char_zero(labels_root)
print("Todas las clases han sido unificadas a '0' en los archivos de etiquetas.")
# Out:
# Todas las clases han sido unificadas a '0' en los archivos de etiquetas.

# %% [markdown]
# ## 4. Entrenamiento de Modelos

# %% [markdown]
# Se entrenarán dos modelos con diferentes arquitecturas para comparar su rendimiento:
# - **YOLOv12 Nano**: Un modelo ligero y rápido, ideal para aplicaciones en tiempo real.
# - **YOLOv12 Medium**: Un modelo ligero y rápido, ideal para aplicaciones en tiempo real.
# - **YOLOv12 Large**: Un modelo más grande y preciso, a costa de una mayor carga computacional.

# %%
# --- Variables y Funciones Auxiliares ---

# Ruta del archivo de configuración del dataset
dataset_path = './dataset_aereo'
yaml_path = f'{dataset_path}/data.yaml'
assert os.path.exists(yaml_path), f"No se encontró data.yaml en {yaml_path}"

# Directorio para guardar los modelos entrenados
output_models_dir = "modelos_entrenados"
os.makedirs(output_models_dir, exist_ok=True)

# Función para limpiar la memoria de la GPU
def clear_gpu_cache():
    torch.cuda.empty_cache()
    torch.cuda.reset_peak_memory_stats()
    print("Caché de la GPU limpiada.")

# Función para visualizar las métricas del entrenamiento
def show_training_metrics(training_path):
    """Muestra las imágenes de resultados y matriz de confusión."""
    results_img_path = os.path.join(training_path, 'results.png')
    confusion_matrix_path = os.path.join(training_path, 'confusion_matrix.png')

    if os.path.exists(results_img_path):
        img_results = cv2.imread(results_img_path)
        img_results = cv2.cvtColor(img_results, cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(12, 8))
        plt.imshow(img_results)
        plt.title("Métricas de Entrenamiento")
        plt.axis('off')
        plt.show()
    else:
        print(f"No se encontró la imagen de resultados en {results_img_path}")

    if os.path.exists(confusion_matrix_path):
        img_cm = cv2.imread(confusion_matrix_path)
        img_cm = cv2.cvtColor(img_cm, cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(12, 8))
        plt.imshow(img_cm)
        plt.title("Matriz de Confusión")
        plt.axis('off')
        plt.show()
    else:
        print(f"No se encontró la matriz de confusión en {confusion_matrix_path}")

# %% [markdown]
# ### 4.1. Entrenamiento del Modelo YOLOv12 Nano

# %%
clear_gpu_cache()

# Cargar el modelo YOLOv12 Nano pre-entrenado
model_n = YOLO("yolo12n.pt")

# Entrenar el modelo
results_n = model_n.train(
    data=yaml_path,
    epochs=50,
    imgsz=640,
    plots=True,
    batch=32,
    name='yolo12n_corrosion' # Nombre del directorio de resultados
)

# Guardar el mejor modelo con el nombre deseado
best_model_path_n = os.path.join(results_n.save_dir, 'weights', 'best.pt')
final_model_name_n = 'modelo-aereo-n.pt'
destination_path_n = os.path.join(output_models_dir, final_model_name_n)

if os.path.exists(best_model_path_n):
    shutil.copy(best_model_path_n, destination_path_n)
    print(f"Modelo Nano guardado en: {destination_path_n}")
else:
    print(f"Error: No se encontró el archivo 'best.pt' en {os.path.join(results_n.save_dir, 'weights')}")
# Out:
# Caché de la GPU limpiada.
# Ultralytics 8.3.228 🚀 Python-3.9.13 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./dataset_aereo/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo12n_corrosion2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/user/work/EONSEA/Articulo-Corrosion/runs/detect/yolo12n_corrosion2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,568,243 parameters, 2,568,227 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2240.0±829.7 MB/s, size: 32.7 KB)
# train: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train... 35259 images, 7284 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35259/35259 2.3Kit/s 15.6s<0.0s
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000097.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000242.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000351.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000492.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000700.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000870.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001085.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001512.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/005238.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/008311.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/014068.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/016913.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/017847.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018347.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018726.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/020864.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/022157.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026345.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026794.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/029246.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031530.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031652.jpg: 2 duplicate labels removed
# train: New cache created: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1065.8±641.6 MB/s, size: 59.2 KB)
# val: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/valid... 569 images, 31 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 569/569 2.1Kit/s 0.3s0.1ss
# val: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/valid/000459.jpg: 2 duplicate labels removed
# val: New cache created: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/valid.cache
# Plotting labels to /home/user/work/EONSEA/Articulo-Corrosion/runs/detect/yolo12n_corrosion2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/user/work/EONSEA/Articulo-Corrosion/runs/detect/yolo12n_corrosion2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      8.36G      1.872      2.384      1.637        191        640: 100% ━━━━━━━━━━━━ 1102/1102 7.8it/s 2:22<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 2.1it/s 4.3s0.2ss
#                    all        569       7828      0.348      0.255      0.209     0.0933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      9.66G      1.848      1.991      1.608        165        640: 100% ━━━━━━━━━━━━ 1102/1102 8.6it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.1it/s 1.5s0.2s
#                    all        569       7828      0.364      0.259      0.219     0.0975
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      9.67G      1.892      1.989       1.65        245        640: 83% ━━━━━━━━━╸── 913/1102 9.2it/s 1:42<20.5s

# %% [markdown]
# ### Visualización de Métricas (YOLOv12 Nano)

# %%
show_training_metrics(results_n.save_dir)

# %% [markdown]
# ### 4.2. Entrenamiento del Modelo YOLOv12 Medium

# %%
clear_gpu_cache()

# Cargar el modelo YOLOv12 Large pre-entrenado
model_l = YOLO("yolo12m.pt")

# Entrenar el modelo
results_l = model_l.train(
    data=yaml_path,
    epochs=50,
    imgsz=640,
    plots=True,
    batch=16, # Se reduce el batch size por el mayor tamaño del modelo
    name='yolo12m_corrosion' # Nombre del directorio de resultados
)

# Guardar el mejor modelo con el nombre deseado
best_model_path_l = os.path.join(results_l.save_dir, 'weights', 'best.pt')
final_model_name_l = 'modelo-aereo-m.pt'
destination_path_l = os.path.join(output_models_dir, final_model_name_l)

if os.path.exists(best_model_path_l):
    shutil.copy(best_model_path_l, destination_path_l)
    print(f"Modelo Large guardado en: {destination_path_l}")
else:
    print(f"Error: No se encontró el archivo 'best.pt' en {os.path.join(results_l.save_dir, 'weights')}")
# Out:
# Caché de la GPU limpiada.
# New https://pypi.org/project/ultralytics/8.3.232 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228 🚀 Python-3.9.13 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./dataset_aereo/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo12m_corrosion2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/user/work/EONSEA/Articulo-Corrosion/runs/detect/yolo12m_corrosion2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLOv12m summary: 292 layers, 20,138,259 parameters, 20,138,243 gradients, 67.7 GFLOPs
#
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2726.2±1250.4 MB/s, size: 34.0 KB)
# train: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/train.cache... 35259 images, 7284 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35259/35259 72.4Mit/s 0.0s
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000097.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000242.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000351.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000492.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000700.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/000870.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001085.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/001512.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/005238.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/008311.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/014068.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/016913.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/017847.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018347.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/018726.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/020864.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/022157.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026345.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/026794.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/029246.jpg: 1 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031530.jpg: 2 duplicate labels removed
# train: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/train/031652.jpg: 2 duplicate labels removed
# albumentations: __init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 406.7±103.1 MB/s, size: 58.0 KB)
# val: Scanning /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/labels/valid.cache... 569 images, 31 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 569/569 399.2Kit/s 0.0s
# val: /home/user/work/EONSEA/Articulo-Corrosion/dataset_aereo/images/valid/000459.jpg: 2 duplicate labels removed
# Plotting labels to /home/user/work/EONSEA/Articulo-Corrosion/runs/detect/yolo12m_corrosion2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/user/work/EONSEA/Articulo-Corrosion/runs/detect/yolo12m_corrosion2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      11.8G      1.778      1.901      1.644         58        640: 100% ━━━━━━━━━━━━ 2204/2204 5.8it/s 6:18<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.405       0.31      0.267      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      11.7G      1.796      1.771      1.632         44        640: 100% ━━━━━━━━━━━━ 2204/2204 6.0it/s 6:05<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 6.9it/s 2.6s0.1s
#                    all        569       7828      0.419      0.308      0.271      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      11.9G      1.871      1.908      1.705         30        640: 100% ━━━━━━━━━━━━ 2204/2204 6.1it/s 5:59<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.0it/s 2.6s0.1s
#                    all        569       7828      0.388      0.264      0.233      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      11.8G      1.866      1.912      1.718        126        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.0it/s 2.6s0.1s
#                    all        569       7828      0.392      0.304      0.266      0.125
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      11.9G      1.779      1.738      1.658         39        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:57<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.6s0.1s
#                    all        569       7828      0.474      0.333      0.312      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      11.8G      1.716      1.611      1.613        139        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        569       7828      0.499      0.351      0.346      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      12.2G      1.669      1.501      1.563        111        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        569       7828      0.539      0.394      0.389      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      12.2G      1.624      1.414      1.527         37        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.567      0.395      0.405      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      12.2G      1.584      1.338      1.496         57        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.583      0.428      0.433      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      12.2G      1.546      1.276      1.468        151        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.1it/s 2.5s0.1s
#                    all        569       7828      0.593      0.432      0.447      0.236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      12.2G      1.517      1.227      1.446         83        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.631      0.459      0.478      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      11.9G       1.49      1.172      1.419         46        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.644      0.463      0.491      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      11.9G      1.459      1.125      1.402         63        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.668       0.47      0.508      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      11.8G      1.435      1.082      1.381        178        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.678      0.487       0.52      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      11.9G      1.411      1.049       1.36        116        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.702      0.495       0.54      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      12.1G       1.39      1.015      1.344        101        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.705       0.51      0.549       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      12.2G      1.367     0.9827      1.329        107        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828       0.73      0.504      0.558       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      11.8G      1.349     0.9587      1.317         89        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.727      0.522      0.569      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      12.2G      1.335     0.9356      1.306        109        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.727      0.528      0.577      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      11.9G      1.314     0.9131      1.292         93        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.731      0.535      0.584      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      12.1G      1.297      0.889      1.276        104        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.745      0.539      0.593      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      11.8G      1.278     0.8688      1.262        101        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828       0.76      0.538      0.599      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      11.9G      1.261     0.8453       1.25         55        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.769       0.54      0.605      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      11.9G      1.246     0.8293      1.239         84        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.756       0.55      0.609      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      11.8G      1.232     0.8139      1.228         96        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.766      0.555      0.614      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      11.9G       1.21     0.7941      1.216         57        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.777      0.556      0.621      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      12.2G      1.191     0.7775      1.202         59        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.783      0.556      0.624       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      12.2G      1.176       0.76      1.194        102        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.787      0.559      0.628      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      12.1G      1.161     0.7445      1.185         95        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.797      0.559      0.632      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      12.2G       1.15     0.7335      1.177         66        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.798      0.561      0.635      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      12.2G      1.134     0.7142       1.17        114        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.798      0.563      0.639      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      11.9G      1.124     0.7036      1.164         77        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.4it/s 2.4s0.1s
#                    all        569       7828      0.802      0.563       0.64      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      11.9G      1.104     0.6895      1.151        107        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.799      0.568      0.643        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      12.2G      1.095     0.6768      1.144        123        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.797      0.573      0.646      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      11.9G       1.08     0.6641      1.137         66        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828        0.8      0.573      0.648      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      11.8G      1.066     0.6516      1.131         97        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.4it/s 2.4s0.1s
#                    all        569       7828      0.808      0.574       0.65      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      12.2G      1.051      0.637      1.118         85        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.802      0.577      0.652      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      12.2G       1.04     0.6268      1.114         76        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.4it/s 2.4s0.1s
#                    all        569       7828      0.803      0.582      0.655      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      12.2G      1.027     0.6153      1.103         95        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.805      0.583      0.658      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      12.1G      1.014     0.6053      1.095         78        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.807      0.586       0.66      0.417
# Closing dataloader mosaic
# albumentations: __init__() got an unexpected keyword argument 'quality_range'
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      12.2G     0.9848     0.5358      1.084         39        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.809      0.586      0.661       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      12.2G     0.9567     0.5145      1.069         35        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.4it/s 2.4s0.1s
#                    all        569       7828      0.809      0.589      0.663      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      12.1G      0.936     0.5018       1.06         48        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.805      0.594      0.666      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      12.1G     0.9159     0.4872      1.046         43        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.4it/s 2.4s0.1s
#                    all        569       7828      0.805      0.595      0.667      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      11.8G     0.8981      0.473      1.037         47        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.799      0.602       0.67       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      11.8G     0.8733     0.4578      1.024         40        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.4it/s 2.4s0.1s
#                    all        569       7828      0.806      0.598      0.671      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      11.8G     0.8592      0.447      1.019         22        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.4it/s 2.4s0.1s
#                    all        569       7828      0.809      0.601      0.674      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      11.9G     0.8423     0.4379      1.012         28        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.3it/s 2.5s0.1s
#                    all        569       7828      0.797      0.611      0.677      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      11.8G     0.8205     0.4254      1.001         46        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.4it/s 2.4s0.1s
#                    all        569       7828      0.811      0.607      0.679       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      12.2G     0.8121     0.4191     0.9969         51        640: 100% ━━━━━━━━━━━━ 2204/2204 6.2it/s 5:55<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.2it/s 2.5s0.1s
#                    all        569       7828      0.804      0.615      0.681      0.443
#
# 50 epochs completed in 5.019 hours.
# Optimizer stripped from /home/user/work/EONSEA/Articulo-Corrosion/runs/detect/yolo12m_corrosion2/weights/last.pt, 40.8MB
# Optimizer stripped from /home/user/work/EONSEA/Articulo-Corrosion/runs/detect/yolo12m_corrosion2/weights/best.pt, 40.8MB
#
# Validating /home/user/work/EONSEA/Articulo-Corrosion/runs/detect/yolo12m_corrosion2/weights/best.pt...
# Ultralytics 8.3.228 🚀 Python-3.9.13 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# YOLOv12m summary (fused): 169 layers, 20,105,683 parameters, 0 gradients, 67.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 0% ──────────── 0/18  0.1s
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# Cell In [7], line 7
#       4 model_l = YOLO("yolo12m.pt")
#       6 # Entrenar el modelo
# ----> 7 results_l = model_l.train(
#       8     data=yaml_path,
#       9     epochs=50,
#      10     imgsz=640,
#      11     plots=True,
#      12     batch=16, # Se reduce el batch size por el mayor tamaño del modelo
#      13     name='yolo12m_corrosion' # Nombre del directorio de resultados
#      14 )
#      16 # Guardar el mejor modelo con el nombre deseado
#      17 best_model_path_l = os.path.join(results_l.save_dir, 'weights', 'best.pt')
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/model.py:778, in Model.train(self, trainer, **kwargs)
#     775     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     776     self.model = self.trainer.model
# --> 778 self.trainer.train()
#     779 # Update model and cfg after training
#     780 if RANK in {-1, 0}:
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/trainer.py:521, in BaseTrainer._do_train(self)
#     519 LOGGER.info(f"\n{epoch - self.start_epoch + 1} epochs completed in {seconds / 3600:.3f} hours.")
#     520 # Do final val with best.pt
# --> 521 self.final_eval()
#     522 if RANK in {-1, 0}:
#     523     if self.args.plots:
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/trainer.py:789, in BaseTrainer.final_eval(self)
#     787 self.validator.args.plots = self.args.plots
#     788 self.validator.args.compile = False  # disable final val compile as too slow
# --> 789 self.metrics = self.validator(model=model)
#     790 self.metrics.pop("fitness", None)
#     791 self.run_callbacks("on_fit_epoch_end")
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/engine/validator.py:223, in BaseValidator.__call__(self, trainer, model)
#     220 with dt[3]:
#     221     preds = self.postprocess(preds)
# --> 223 self.update_metrics(preds, batch)
#     224 if self.args.plots and batch_i < 3 and RANK in {-1, 0}:
#     225     self.plot_val_samples(batch, batch_i)
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/models/yolo/detect/val.py:193, in DetectionValidator.update_metrics(self, preds, batch)
#     191 # Evaluate
#     192 if self.args.plots:
# --> 193     self.confusion_matrix.process_batch(predn, pbatch, conf=self.args.conf)
#     194     if self.args.visualize:
#     195         self.confusion_matrix.plot_matches(batch["img"][si], pbatch["im_file"], self.save_dir)
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/utils/metrics.py:405, in ConfusionMatrix.process_batch(self, detections, batch, conf, iou_thres)
#     402         self._append_matches("FN", batch, i)
#     403     return
# --> 405 detections = {k: detections[k][detections["conf"] > conf] for k in detections}
#     406 gt_classes = gt_cls.int().tolist()
#     407 detection_classes = detections["cls"].int().tolist()
#
# File ~/work/envs/yoloenv/lib/python3.9/site-packages/ultralytics/utils/metrics.py:405, in <dictcomp>(.0)
#     402         self._append_matches("FN", batch, i)
#     403     return
# --> 405 detections = {k: detections[k][detections["conf"] > conf] for k in detections}
#     406 gt_classes = gt_cls.int().tolist()
#     407 detection_classes = detections["cls"].int().tolist()
#
# AcceleratorError: CUDA error: invalid argument
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# ### Visualización de Métricas (YOLOv12 Medium)

# %%
show_training_metrics(results_l.save_dir)

# %% [markdown]
# ### 4.3. Entrenamiento del Modelo YOLOv12 Large

# %%
clear_gpu_cache()

# Cargar el modelo YOLOv12 Large pre-entrenado
model_l = YOLO("yolo12l.pt")

# Entrenar el modelo
results_l = model_l.train(
    data=yaml_path,
    epochs=50,
    imgsz=640,
    plots=True,
    batch=16, # Se reduce el batch size por el mayor tamaño del modelo
    name='yolo12l_corrosion' # Nombre del directorio de resultados
)

# Guardar el mejor modelo con el nombre deseado
best_model_path_l = os.path.join(results_l.save_dir, 'weights', 'best.pt')
final_model_name_l = 'modelo-aereo-l.pt'
destination_path_l = os.path.join(output_models_dir, final_model_name_l)

if os.path.exists(best_model_path_l):
    shutil.copy(best_model_path_l, destination_path_l)
    print(f"Modelo Large guardado en: {destination_path_l}")
else:
    print(f"Error: No se encontró el archivo 'best.pt' en {os.path.join(results_l.save_dir, 'weights')}")

# %% [markdown]
# ### Visualización de Métricas (YOLOv12 Large)

# %%
show_training_metrics(results_l.save_dir)
